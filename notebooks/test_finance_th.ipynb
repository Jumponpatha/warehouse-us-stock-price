# %%
import pandas as pd
import yfinance as yf
from datetime import datetime, timezone
from sqlalchemy import create_engine
import psycopg2

# %%
stock = yf.Ticker('GOOGL')

# %%
stock.info
# Out:
# {'address1': '1600 Amphitheatre Parkway',
#  'city': 'Mountain View',
#  'state': 'CA',
#  'zip': '94043',
#  'country': 'United States',
#  'phone': '650-253-0000',
#  'website': 'https://abc.xyz',
#  'industry': 'Internet Content & Information',
#  'industryKey': 'internet-content-information',
#  'industryDisp': 'Internet Content & Information',
#  'sector': 'Communication Services',
#  'sectorKey': 'communication-services',
#  'sectorDisp': 'Communication Services',
#  'longBusinessSummary': 'Alphabet Inc. offers various products and platforms in the United States, Europe, the Middle East, Africa, the Asia-Pacific, Canada, and Latin America. It operates through Google Services, Google Cloud, and Other Bets segments. The Google Services segment provides products and services, including ads, Android, Chrome, devices, Gmail, Google Drive, Google Maps, Google Photos, Google Play, Search, and YouTube. It is also involved in the sale of apps and in-app purchases and digital content in the Google Play and YouTube; and devices, as well as in the provision of YouTube consumer subscription services. The Google Cloud segment offers AI infrastructure, Vertex AI platform, cybersecurity, data and analytics, and other services; Google Workspace that include cloud-based communication and collaboration tools for enterprises, such as Calendar, Gmail, Docs, Drive, and Meet; and other services for enterprise customers. The Other Bets segment sells healthcare-related and internet services. The company was incorporated in 1998 and is headquartered in Mountain View, California.',
#  'fullTimeEmployees': 190167,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Sundar  Pichai',
#    'age': 51,
#    'title': 'CEO & Director',
#    'yearBorn': 1973,
#    'fiscalYear': 2024,
#    'totalPay': 10319413,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Ruth M. Porat',
#    'age': 66,
#    'title': 'President & Chief Investment Officer',
#    'yearBorn': 1958,
#    'fiscalYear': 2024,
#    'totalPay': 3023363,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Lawrence Edward Page II',
#    'age': 51,
#    'title': 'Co-Founder & Director',
#    'yearBorn': 1973,
#    'fiscalYear': 2024,
#    'totalPay': 1,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Sergey  Brin',
#    'age': 50,
#    'title': 'Co-Founder & Director',
#    'yearBorn': 1974,
#    'fiscalYear': 2024,
#    'totalPay': 1,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Anat  Ashkenazi',
#    'age': 51,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1973,
#    'fiscalYear': 2024,
#    'totalPay': 11455556,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. J. Kent Walker',
#    'age': 63,
#    'title': 'President of Global Affairs, Chief Legal Officer & Company Secretary',
#    'yearBorn': 1961,
#    'fiscalYear': 2024,
#    'totalPay': 3019696,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Philipp  Schindler',
#    'age': 53,
#    'title': 'Senior Vice President & Chief Business Officer of Google',
#    'yearBorn': 1971,
#    'fiscalYear': 2024,
#    'totalPay': 3051699,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Amie Thuener O'Toole",
#    'age': 49,
#    'title': 'Corporate Controller, Chief Accounting Officer & VP',
#    'yearBorn': 1975,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Ellen  West',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Fiona Clare Cicconi',
#    'age': 58,
#    'title': 'Chief People Officer',
#    'yearBorn': 1966,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 7,
#  'boardRisk': 9,
#  'compensationRisk': 10,
#  'shareHolderRightsRisk': 10,
#  'overallRisk': 10,
#  'governanceEpochDate': 1761955200,
#  'compensationAsOfEpochDate': 1735603200,
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 285.02,
#  'open': 287.86,
#  'dayLow': 279.46,
#  'dayHigh': 288.32,
#  'regularMarketPreviousClose': 285.02,
#  'regularMarketOpen': 287.86,
#  'regularMarketDayLow': 279.46,
#  'regularMarketDayHigh': 288.32,
#  'dividendRate': 0.84,
#  'dividendYield': 0.29,
#  'exDividendDate': 1765152000,
#  'payoutRatio': 0.0809,
#  'beta': 1.082,
#  'trailingPE': 27.710968,
#  'forwardPE': 31.29855,
#  'volume': 15410300,
#  'regularMarketVolume': 15410300,
#  'averageVolume': 34043723,
#  'averageVolume10days': 32069000,
#  'averageDailyVolume10Day': 32069000,
#  'bid': 278.03,
#  'ask': 288.5,
#  'bidSize': 6,
#  'askSize': 1,
#  'marketCap': 3396662984704,
#  'fiftyTwoWeekLow': 140.53,
#  'fiftyTwoWeekHigh': 293.95,
#  'allTimeHigh': 293.95,
#  'allTimeLow': 2.401401,
#  'priceToSalesTrailing12Months': 8.811606,
#  'fiftyDayAverage': 258.2604,
#  'twoHundredDayAverage': 197.46175,
#  'trailingAnnualDividendRate': 1.02,
#  'trailingAnnualDividendYield': 0.0035786964,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 3385035325440,
#  'profitMargins': 0.32233003,
#  'floatShares': 10796827580,
#  'sharesOutstanding': 5818000000,
#  'sharesShort': 67264072,
#  'sharesShortPriorMonth': 59536136,
#  'sharesShortPreviousMonthDate': 1759190400,
#  'dateShortInterest': 1761868800,
#  'sharesPercentSharesOut': 0.0056,
#  'heldPercentInsiders': 0.00569,
#  'heldPercentInstitutions': 0.81284,
#  'shortRatio': 2.11,
#  'shortPercentOfFloat': 0.0116,
#  'impliedSharesOutstanding': 12112122294,
#  'bookValue': 32.033,
#  'priceToBook': 8.754565,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1759190400,
#  'earningsQuarterlyGrowth': 0.33,
#  'netIncomeToCommon': 124250996736,
#  'trailingEps': 10.12,
#  'forwardEps': 8.96,
#  'lastSplitFactor': '20:1',
#  'lastSplitDate': 1658102400,
#  'enterpriseToRevenue': 8.781,
#  'enterpriseToEbitda': 23.317,
#  '52WeekChange': 0.60015714,
#  'SandP52WeekChange': 0.1276716,
#  'lastDividendValue': 0.21,
#  'lastDividendDate': 1757289600,
#  'quoteType': 'EQUITY',
#  'currentPrice': 280.435,
#  'targetHighPrice': 360.0,
#  'targetLowPrice': 185.0,
#  'targetMeanPrice': 319.34888,
#  'targetMedianPrice': 329.0,
#  'recommendationMean': 1.48485,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 54,
#  'totalCash': 98496004096,
#  'totalCashPerShare': 8.162,
#  'ebitda': 145174003712,
#  'totalDebt': 44195000320,
#  'quickRatio': 1.563,
#  'currentRatio': 1.747,
#  'totalRevenue': 385476001792,
#  'debtToEquity': 11.424,
#  'revenuePerShare': 31.714,
#  'returnOnAssets': 0.16275999,
#  'returnOnEquity': 0.3545,
#  'grossProfits': 228095000576,
#  'freeCashflow': 47997751296,
#  'operatingCashflow': 151424008192,
#  'earningsGrowth': 0.353,
#  'revenueGrowth': 0.159,
#  'grossMargins': 0.59172,
#  'ebitdaMargins': 0.37660998,
#  'operatingMargins': 0.30512,
#  'financialCurrency': 'USD',
#  'symbol': 'GOOGL',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'regularMarketChangePercent': -1.608656,
#  'regularMarketPrice': 280.435,
#  'shortName': 'Alphabet Inc.',
#  'longName': 'Alphabet Inc.',
#  'corporateActions': [{'header': 'Dividend',
#    'message': 'GOOGL announced a cash dividend of 0.21 with an ex-date of Dec. 8, 2025',
#    'meta': {'eventType': 'DIVIDEND',
#     'dateEpochMs': 1765170000000,
#     'amount': '0.21'}}],
#  'regularMarketTime': 1763481351,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_29096',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 1092922200000,
#  'regularMarketChange': -4.5849915,
#  'regularMarketDayRange': '279.46 - 288.32',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 34043723,
#  'fiftyTwoWeekLowChange': 139.905,
#  'fiftyTwoWeekLowChangePercent': 0.99555254,
#  'fiftyTwoWeekRange': '140.53 - 293.95',
#  'fiftyTwoWeekHighChange': -13.515015,
#  'fiftyTwoWeekHighChangePercent': -0.045977253,
#  'fiftyTwoWeekChangePercent': 60.015713,
#  'dividendDate': 1765756800,
#  'earningsTimestamp': 1761768000,
#  'earningsTimestampStart': 1761768000,
#  'earningsTimestampEnd': 1761768000,
#  'earningsCallTimestampStart': 1761773400,
#  'earningsCallTimestampEnd': 1761773400,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 10.12,
#  'epsForward': 8.96,
#  'epsCurrentYear': 10.48889,
#  'priceEpsCurrentYear': 26.736385,
#  'fiftyDayAverageChange': 22.174591,
#  'fiftyDayAverageChangePercent': 0.08586136,
#  'twoHundredDayAverageChange': 82.97325,
#  'twoHundredDayAverageChangePercent': 0.42019913,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '1.5 - Strong Buy',
#  'marketState': 'REGULAR',
#  'trailingPegRatio': 1.6147}

# %%
sp500_list = get_sp500_list()

        # Initialize an empty list to store data
data_list = []

for symbol in sp500_list:
            ticker = yf.Ticker(symbol)
            info = ticker.info  # Full metadata

            data_list.append({
                "Exchange": info.get("exchange"),
                "Symbol": symbol,
                "Shortname": info.get("shortName"),
                "Longname": info.get("longName"),
                "Sector": info.get("sector"),
                "Industry": info.get("industry"),
                "Current_Price": info.get("currentPrice"),
                "Market_Cap": info.get("marketCap"),
                "Ebitda": info.get("ebitda"),
                "Revenue_Growth": info.get("revenueGrowth"),
            })

        sp_profile_df = pd.DataFrame(data_list)

# %%
stock.financials
# Out:
#                                                       2025-01-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.330000e-01
# Normalized EBITDA                                   8.613700e+10
# Total Unusual Items                                 0.000000e+00
# Total Unusual Items Excluding Goodwill              0.000000e+00
# Net Income From Continuing Operation Net Minori...  7.288000e+10
# Reconciled Depreciation                             1.864000e+09
# Reconciled Cost Of Revenue                          3.263900e+10
# EBITDA                                              8.613700e+10
# EBIT                                                8.427300e+10
# Net Interest Income                                 1.539000e+09
# Interest Expense                                    2.470000e+08
# Interest Income                                     1.786000e+09
# Normalized Income                                   7.288000e+10
# Net Income From Continuing And Discontinued Ope...  7.288000e+10
# Total Expenses                                      4.904400e+10
# Total Operating Income As Reported                  8.145300e+10
# Diluted Average Shares                              2.480400e+10
# Basic Average Shares                                2.455500e+10
# Diluted EPS                                         2.940000e+00
# Basic EPS                                           2.970000e+00
# Diluted NI Availto Com Stockholders                 7.288000e+10
# Net Income Common Stockholders                      7.288000e+10
# Net Income                                          7.288000e+10
# Net Income Including Noncontrolling Interests       7.288000e+10
# Net Income Continuous Operations                    7.288000e+10
# Tax Provision                                       1.114600e+10
# Pretax Income                                       8.402600e+10
# Other Income Expense                                1.034000e+09
# Other Non Operating Income Expenses                 1.034000e+09
# Special Income Charges                              0.000000e+00
# Restructuring And Mergern Acquisition               0.000000e+00
# Net Non Operating Interest Income Expense           1.539000e+09
# Interest Expense Non Operating                      2.470000e+08
# Interest Income Non Operating                       1.786000e+09
# Operating Income                                    8.145300e+10
# Operating Expense                                   1.640500e+10
# Research And Development                            1.291400e+10
# Selling General And Administration                  3.491000e+09
# Gross Profit                                        9.785800e+10
# Cost Of Revenue                                     3.263900e+10
# Total Revenue                                       1.304970e+11
# Operating Revenue                                   1.304970e+11
#
#                                                       2024-01-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.200000e-01
# Normalized EBITDA                                   3.558300e+10
# Total Unusual Items                                 0.000000e+00
# Total Unusual Items Excluding Goodwill              0.000000e+00
# Net Income From Continuing Operation Net Minori...  2.976000e+10
# Reconciled Depreciation                             1.508000e+09
# Reconciled Cost Of Revenue                          1.662100e+10
# EBITDA                                              3.558300e+10
# EBIT                                                3.407500e+10
# Net Interest Income                                 6.090000e+08
# Interest Expense                                    2.570000e+08
# Interest Income                                     8.660000e+08
# Normalized Income                                   2.976000e+10
# Net Income From Continuing And Discontinued Ope...  2.976000e+10
# Total Expenses                                      2.795000e+10
# Total Operating Income As Reported                  3.297200e+10
# Diluted Average Shares                              2.494000e+10
# Basic Average Shares                                2.469000e+10
# Diluted EPS                                         1.190000e+00
# Basic EPS                                           1.210000e+00
# Diluted NI Availto Com Stockholders                 2.976000e+10
# Net Income Common Stockholders                      2.976000e+10
# Net Income                                          2.976000e+10
# Net Income Including Noncontrolling Interests       2.976000e+10
# Net Income Continuous Operations                    2.976000e+10
# Tax Provision                                       4.058000e+09
# Pretax Income                                       3.381800e+10
# Other Income Expense                                2.370000e+08
# Other Non Operating Income Expenses                 2.370000e+08
# Special Income Charges                              0.000000e+00
# Restructuring And Mergern Acquisition               0.000000e+00
# Net Non Operating Interest Income Expense           6.090000e+08
# Interest Expense Non Operating                      2.570000e+08
# Interest Income Non Operating                       8.660000e+08
# Operating Income                                    3.297200e+10
# Operating Expense                                   1.132900e+10
# Research And Development                            8.675000e+09
# Selling General And Administration                  2.654000e+09
# Gross Profit                                        4.430100e+10
# Cost Of Revenue                                     1.662100e+10
# Total Revenue                                       6.092200e+10
# Operating Revenue                                   6.092200e+10
#
#                                                       2023-01-31    2022-01-31
# Tax Effect Of Unusual Items                        -2.841300e+08  0.000000e+00
# Tax Rate For Calcs                                  2.100000e-01  1.900000e-02
# Normalized EBITDA                                   7.339000e+09  1.135100e+10
# Total Unusual Items                                -1.353000e+09  0.000000e+00
# Total Unusual Items Excluding Goodwill             -1.353000e+09  0.000000e+00
# Net Income From Continuing Operation Net Minori...  4.368000e+09  9.752000e+09
# Reconciled Depreciation                             1.543000e+09  1.174000e+09
# Reconciled Cost Of Revenue                          1.161800e+10  9.439000e+09
# EBITDA                                              5.986000e+09  1.135100e+10
# EBIT                                                4.443000e+09  1.017700e+10
# Net Interest Income                                 5.000000e+06 -2.070000e+08
# Interest Expense                                    2.620000e+08  2.360000e+08
# Interest Income                                     2.670000e+08  2.900000e+07
# Normalized Income                                   5.436870e+09  9.752000e+09
# Net Income From Continuing And Discontinued Ope...  4.368000e+09  9.752000e+09
# Total Expenses                                      2.139700e+10  1.687300e+10
# Total Operating Income As Reported                  4.224000e+09  1.004100e+10
# Diluted Average Shares                              2.507000e+10  2.535000e+10
# Basic Average Shares                                2.487000e+10  2.496000e+10
# Diluted EPS                                         1.740000e-01  3.850000e-01
# Basic EPS                                           1.760000e-01  3.910000e-01
# Diluted NI Availto Com Stockholders                 4.368000e+09  9.752000e+09
# Net Income Common Stockholders                      4.368000e+09  9.752000e+09
# Net Income                                          4.368000e+09  9.752000e+09
# Net Income Including Noncontrolling Interests       4.368000e+09  9.752000e+09
# Net Income Continuous Operations                    4.368000e+09  9.752000e+09
# Tax Provision                                      -1.870000e+08  1.890000e+08
# Pretax Income                                       4.181000e+09  9.941000e+09
# Other Income Expense                               -1.401000e+09  1.070000e+08
# Other Non Operating Income Expenses                -4.800000e+07  1.070000e+08
# Special Income Charges                             -1.353000e+09  0.000000e+00
# Restructuring And Mergern Acquisition               1.353000e+09  0.000000e+00
# Net Non Operating Interest Income Expense           5.000000e+06 -2.070000e+08
# Interest Expense Non Operating                      2.620000e+08  2.360000e+08
# Interest Income Non Operating                       2.670000e+08  2.900000e+07
# Operating Income                                    5.577000e+09  1.004100e+10
# Operating Expense                                   9.779000e+09  7.434000e+09
# Research And Development                            7.339000e+09  5.268000e+09
# Selling General And Administration                  2.440000e+09  2.166000e+09
# Gross Profit                                        1.535600e+10  1.747500e+10
# Cost Of Revenue                                     1.161800e+10  9.439000e+09
# Total Revenue                                       2.697400e+10  2.691400e+10
# Operating Revenue                                   2.697400e+10  2.691400e+10

# %%
# Get S&P 500 company list
symbol_list = ['GOOGL', 'NVDA','MSFT']

# Initialize an empty list to store data
data_list = []

for symbol in symbol_list:
    ticker = yf.Ticker(symbol)
    info = ticker.info  # Full metadata
# 'address1': '2788 San Tomas Expressway',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95051',
#  'country': 'United States',
#  'phone': '408 486 2000',
#  'website': 'https://www.nvidia.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',

    data_list.append({
        "Exchange": info.get("exchange"),
        "Symbol": symbol,
        "Short_Name": info.get("shortName"),
        "Long_Name": info.get("longName"),
        "Long_Business_Sum":info.get("longBusinessSummary"),
        "Sector": info.get("sector"),
        "Industry": info.get("industry"),
        "Current_Price": info.get("currentPrice"),
        "Market_Cap": info.get("marketCap"),
        "Ebitda": info.get("ebitda"),
        "All_Time_High": info.get("allTimeHigh"),
        "All_Time_Low": info.get("allTimeLow"),
        "Price_To_Sales_TTM": info.get("priceToSalesTrailing12Months"),
        "Fifty_Day_Avg": info.get("fiftyDayAverage"),
        "Two_Hundred_Day_Avg": info.get("twoHundredDayAverage"),
        "Trailing_Annual_Dividend_Rate": info.get("trailingAnnualDividendRate"),
        "Trailing_Annual_Dividend_Yield": info.get("trailingAnnualDividendYield"),
        "Currency": info.get("currency"),
        "Tradeable": info.get("tradeable"),
        "Quote_Type": info.get("quoteType"),
        "Enterprise_Value": info.get("enterpriseValue"),
        "Profit_Margins": info.get("profitMargins"),
        "Float_Shares": info.get("floatShares"),
        "Shares_Outstanding": info.get("sharesOutstanding"),
        "Shares_Short": info.get("sharesShort"),
        "Shares_Short_Prior_Month": info.get("sharesShortPriorMonth"),
        "Shares_Short_Prev_Month_Date": info.get("sharesShortPreviousMonthDate"),
        "Date_Short_Interest": info.get("dateShortInterest"),
        "Shares_Percent_Shares_Out": info.get("sharesPercentSharesOut"),
        "Short_Ratio": info.get("shortRatio"),
        "Short_Percent_Of_Float": info.get("shortPercentOfFloat"),
        "Held_Percent_Insiders": info.get("heldPercentInsiders"),
        "Held_Percent_Institutions": info.get("heldPercentInstitutions"),
        "Book_Value": info.get("bookValue"),
        "Price_To_Book": info.get("priceToBook"),
        "Last_Fiscal_Year_End": info.get("lastFiscalYearEnd"),
        "Next_Fiscal_Year_End": info.get("nextFiscalYearEnd"),
        "Most_Recent_Quarter": info.get("mostRecentQuarter"),
        "Earnings_Quarterly_Growth": info.get("earningsQuarterlyGrowth"),
        "Net_Income_To_Common": info.get("netIncomeToCommon"),
        "Average_Analyst_Rating": info.get("averageAnalystRating"),
        "Officers_0_name": info.get("companyOfficers")[0].get("name"),
        "Officers_0_title": info.get("companyOfficers")[0].get("title"),
        "Officers_0_yearBorn": info.get("companyOfficers")[0].get("yearBorn"),
        "Officers_0_fiscalYear": info.get("companyOfficers")[0].get("fiscalYear"),
        "Officers_0_totalPay": info.get("companyOfficers")[0].get("totalPay"),
        "Officers_1_name": info.get("companyOfficers")[1].get("name"),
        "Officers_1_title": info.get("companyOfficers")[1].get("title"),
        "Officers_1_yearBorn": info.get("companyOfficers")[1].get("yearBorn"),
        "Officers_1_fiscalYear": info.get("companyOfficers")[1].get("fiscalYear"),
        "Officers_1_totalPay": info.get("companyOfficers")[1].get("totalPay"),
        "Officers_2_name": info.get("companyOfficers")[2].get("name"),
        "Officers_2_title": info.get("companyOfficers")[2].get("title"),
        "Officers_2_yearBorn": info.get("companyOfficers")[2].get("yearBorn"),
        "Officers_2_fiscalYear": info.get("companyOfficers")[2].get("fiscalYear"),
        "Officers_2_totalPay": info.get("companyOfficers")[2].get("totalPay"),
        "Officers_3_name": info.get("companyOfficers")[3].get("name"),
        "Officers_3_title": info.get("companyOfficers")[3].get("title"),
        "Officers_3_yearBorn": info.get("companyOfficers")[3].get("yearBorn"),
        "Officers_3_fiscalYear": info.get("companyOfficers")[3].get("fiscalYear"),
        "Officers_3_totalPay": info.get("companyOfficers")[3].get("totalPay"),
        "Officers_4_name": info.get("companyOfficers")[4].get("name"),
        "Officers_4_title": info.get("companyOfficers")[4].get("title"),
        "Officers_4_yearBorn": info.get("companyOfficers")[4].get("yearBorn"),
        "Officers_4_fiscalYear": info.get("companyOfficers")[4].get("fiscalYear"),
        "Officers_4_totalPay": info.get("companyOfficers")[4].get("totalPay"),
        "Officers_5_name": info.get("companyOfficers")[5].get("name"),
        "Officers_5_title": info.get("companyOfficers")[5].get("title"),
        "Officers_5_yearBorn": info.get("companyOfficers")[5].get("yearBorn"),
        "Officers_5_fiscalYear": info.get("companyOfficers")[5].get("fiscalYear"),
        "Officers_5_totalPay": info.get("companyOfficers")[5].get("totalPay"),
        "Officers_6_name": info.get("companyOfficers")[6].get("name"),
        "Officers_6_title": info.get("companyOfficers")[6].get("title"),
        "Officers_6_yearBorn": info.get("companyOfficers")[6].get("yearBorn"),
        "Officers_6_fiscalYear": info.get("companyOfficers")[6].get("fiscalYear"),
        "Officers_6_totalPay": info.get("companyOfficers")[6].get("totalPay"),
        "Officers_7_name": info.get("companyOfficers")[7].get("name"),
        "Officers_7_title": info.get("companyOfficers")[7].get("title"),
        "Officers_7_yearBorn": info.get("companyOfficers")[7].get("yearBorn"),
        "Officers_7_fiscalYear": info.get("companyOfficers")[7].get("fiscalYear"),
        "Officers_7_totalPay": info.get("companyOfficers")[7].get("totalPay"),
        "Officers_8_name": info.get("companyOfficers")[8].get("name"),
        "Officers_8_title": info.get("companyOfficers")[8].get("title"),
        "Officers_8_yearBorn": info.get("companyOfficers")[8].get("yearBorn"),
        "Officers_8_fiscalYear": info.get("companyOfficers")[8].get("fiscalYear"),
        "Officers_8_totalPay": info.get("companyOfficers")[8].get("totalPay"),
        "Officers_9_name": info.get("companyOfficers")[9].get("name"),
        "Officers_9_title": info.get("companyOfficers")[9].get("title"),
        "Officers_9_yearBorn": info.get("companyOfficers")[9].get("yearBorn"),
        "Officers_9_fiscalYear": info.get("companyOfficers")[9].get("fiscalYear"),
        "Officers_9_totalPay": info.get("companyOfficers")[9].get("totalPay"),
    })

df = pd.DataFrame(data_list)
df
# Out:
#   Exchange Symbol             Short_Name              Long_Name  \
# 0      NMS  GOOGL          Alphabet Inc.          Alphabet Inc.
# 1      NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation
# 2      NMS   MSFT  Microsoft Corporation  Microsoft Corporation
#
#                                    Long_Business_Sum                  Sector  \
# 0  Alphabet Inc. offers various products and plat...  Communication Services
# 1  NVIDIA Corporation, a computing infrastructure...              Technology
# 2  Microsoft Corporation develops and supports so...              Technology
#
#                          Industry  Current_Price     Market_Cap        Ebitda  \
# 0  Internet Content & Information         284.80  3449532186624  145174003712
# 1                  Semiconductors         183.48  4474384941056   98280996864
# 2       Software - Infrastructure         491.64  3654442024960  166436995072
#
#    ...    Officers_8_name                                   Officers_8_title  \
# 0  ...    Ms. Ellen  West               Vice President of Investor Relations
# 1  ...  Mr. Toshiya  Hari  Vice President of Investor Relations & Strateg...
# 2  ...  Jonathan  Neilson               Vice President of Investor Relations
#
#    Officers_8_yearBorn  Officers_8_fiscalYear  Officers_8_totalPay  \
# 0                 None                   2024                 None
# 1                 None                   2025                 None
# 2                 None                   2025                 None
#
#            Officers_9_name                                Officers_9_title  \
# 0  Ms. Fiona Clare Cicconi                            Chief People Officer
# 1  Ms. Mylene  Mangalindan                  VP of Corporate Communications
# 2   Mr. Jonathan M. Palmer  Corporate Vice President & Chief Legal Officer
#
#   Officers_9_yearBorn  Officers_9_fiscalYear Officers_9_totalPay
# 0              1966.0                   2024                None
# 1                 NaN                   2025                None
# 2                 NaN                   2025                None
#
# [3 rows x 91 columns]

# %%
# {'maxAge': 1,
#    'name': 'Mr. Jen-Hsun  Huang',
#    'age': 61,
#    'title': 'Co-Founder, CEO, President & Director',
#    'yearBorn': 1963,
#    'fiscalYear': 2025,
#    'totalPay': 11054945,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},

# %%
# Get S&P 500 company list
symbol_list = ['QQQM', 'SPY','QQQ','VOO']

# Initialize an empty list to store data
data_list = []

for symbol in symbol_list:
    ticker = yf.Ticker(symbol)
    info = ticker.info  # Full metadata

    data_list.append({
        "Exchange": info.get("exchange"),
        "Symbol": symbol,
        "Short_Name": info.get("shortName"),
        "Long_Name": info.get("longName"),
        "Long_Business_Sum": info.get("longBusinessSummary"),
        "Sector": info.get("sector"),
        "Industry": info.get("industry"),
        "Current_Price": info.get("currentPrice"),
        "Market_Cap": info.get("marketCap"),
        "Ebitda": info.get("ebitda"),
        "All_Time_High": info.get("allTimeHigh"),
        "All_Time_Low": info.get("allTimeLow"),
        "Price_To_Sales_TTM": info.get("priceToSalesTrailing12Months"),
        "Fifty_Day_Avg": info.get("fiftyDayAverage"),
        "Two_Hundred_Day_Avg": info.get("twoHundredDayAverage"),
        "Trailing_Annual_Dividend_Rate": info.get("trailingAnnualDividendRate"),
        "Trailing_Annual_Dividend_Yield": info.get("trailingAnnualDividendYield"),
        "Currency": info.get("currency"),
        "Tradeable": info.get("tradeable"),
        "Quote_Type": info.get("quoteType"),
        "Enterprise_Value": info.get("enterpriseValue"),
        "Profit_Margins": info.get("profitMargins"),
        "Float_Shares": info.get("floatShares"),
        "Shares_Outstanding": info.get("sharesOutstanding"),
        "Shares_Short": info.get("sharesShort"),
        "Shares_Short_Prior_Month": info.get("sharesShortPriorMonth"),
        "Shares_Short_Prev_Month_Date": info.get("sharesShortPreviousMonthDate"),
        "Date_Short_Interest": info.get("dateShortInterest"),
        "Shares_Percent_Shares_Out": info.get("sharesPercentSharesOut"),
        "Short_Ratio": info.get("shortRatio"),
        "Short_Percent_Of_Float": info.get("shortPercentOfFloat"),
        "Last_Fiscal_Year_End": info.get("lastFiscalYearEnd"),
        "Next_Fiscal_Year_End": info.get("nextFiscalYearEnd"),
        "Most_Recent_Quarter": info.get("mostRecentQuarter"),
        "Earnings_Quarterly_Growth": info.get("earningsQuarterlyGrowth"),
        "Net_Income_To_Common": info.get("netIncomeToCommon"),
        "Average_Analyst_Rating": info.get("averageAnalystRating"),
# "Officers_0_name": info.get("companyOfficers")[0].get("name"),
# "Officers_0_title": info.get("companyOfficers")[0].get("title"),
# "Officers_0_yearBorn": info.get("companyOfficers")[0].get("yearBorn"),
# "Officers_0_fiscalYear": info.get("companyOfficers")[0].get("fiscalYear"),
# "Officers_0_totalPay": info.get("companyOfficers")[0].get("totalPay"),

# "Officers_1_name": info.get("companyOfficers")[1].get("name"),
# "Officers_1_title": info.get("companyOfficers")[1].get("title"),
# "Officers_1_yearBorn": info.get("companyOfficers")[1].get("yearBorn"),
# "Officers_1_fiscalYear": info.get("companyOfficers")[1].get("fiscalYear"),
# "Officers_1_totalPay": info.get("companyOfficers")[1].get("totalPay"),

# "Officers_2_name": info.get("companyOfficers")[2].get("name"),
# "Officers_2_title": info.get("companyOfficers")[2].get("title"),
# "Officers_2_yearBorn": info.get("companyOfficers")[2].get("yearBorn"),
# "Officers_2_fiscalYear": info.get("companyOfficers")[2].get("fiscalYear"),
# "Officers_2_totalPay": info.get("companyOfficers")[2].get("totalPay"),

# "Officers_3_name": info.get("companyOfficers")[3].get("name"),
# "Officers_3_title": info.get("companyOfficers")[3].get("title"),
# "Officers_3_yearBorn": info.get("companyOfficers")[3].get("yearBorn"),
# "Officers_3_fiscalYear": info.get("companyOfficers")[3].get("fiscalYear"),
# "Officers_3_totalPay": info.get("companyOfficers")[3].get("totalPay"),

# "Officers_4_name": info.get("companyOfficers")[4].get("name"),
# "Officers_4_title": info.get("companyOfficers")[4].get("title"),
# "Officers_4_yearBorn": info.get("companyOfficers")[4].get("yearBorn"),
# "Officers_4_fiscalYear": info.get("companyOfficers")[4].get("fiscalYear"),
# "Officers_4_totalPay": info.get("companyOfficers")[4].get("totalPay"),

# "Officers_5_name": info.get("companyOfficers")[5].get("name"),
# "Officers_5_title": info.get("companyOfficers")[5].get("title"),
# "Officers_5_yearBorn": info.get("companyOfficers")[5].get("yearBorn"),
# "Officers_5_fiscalYear": info.get("companyOfficers")[5].get("fiscalYear"),
# "Officers_5_totalPay": info.get("companyOfficers")[5].get("totalPay"),

# "Officers_6_name": info.get("companyOfficers")[6].get("name"),
# "Officers_6_title": info.get("companyOfficers")[6].get("title"),
# "Officers_6_yearBorn": info.get("companyOfficers")[6].get("yearBorn"),
# "Officers_6_fiscalYear": info.get("companyOfficers")[6].get("fiscalYear"),
# "Officers_6_totalPay": info.get("companyOfficers")[6].get("totalPay"),

# "Officers_7_name": info.get("companyOfficers")[7].get("name"),
# "Officers_7_title": info.get("companyOfficers")[7].get("title"),
# "Officers_7_yearBorn": info.get("companyOfficers")[7].get("yearBorn"),
# "Officers_7_fiscalYear": info.get("companyOfficers")[7].get("fiscalYear"),
# "Officers_7_totalPay": info.get("companyOfficers")[7].get("totalPay"),

# "Officers_8_name": info.get("companyOfficers")[8].get("name"),
# "Officers_8_title": info.get("companyOfficers")[8].get("title"),
# "Officers_8_yearBorn": info.get("companyOfficers")[8].get("yearBorn"),
# "Officers_8_fiscalYear": info.get("companyOfficers")[8].get("fiscalYear"),
# "Officers_8_totalPay": info.get("companyOfficers")[8].get("totalPay"),

# "Officers_9_name": info.get("companyOfficers")[9].get("name"),
# "Officers_9_title": info.get("companyOfficers")[9].get("title"),
# "Officers_9_yearBorn": info.get("companyOfficers")[9].get("yearBorn"),
# "Officers_9_fiscalYear": info.get("companyOfficers")[9].get("fiscalYear"),
# "Officers_9_totalPay": info.get("companyOfficers")[9].get("totalPay"),

    })


df = pd.DataFrame(data_list)
df
# Out:
#   Exchange Symbol                   Short_Name               Long_Name  \
# 0      NGM   QQQM       Invesco NASDAQ 100 ETF  Invesco NASDAQ 100 ETF
# 1      PCX    SPY                 SPDR S&P 500        SPDR S&P 500 ETF
# 2      NGM    QQQ  Invesco QQQ Trust, Series 1       Invesco QQQ Trust
# 3      PCX    VOO         Vanguard S&P 500 ETF    Vanguard S&P 500 ETF
#
#                                    Long_Business_Sum Sector Industry  \
# 0  The fund generally will invest at least 90% of...   None     None
# 1  The trust seeks to achieve its investment obje...   None     None
# 2  To maintain the correspondence between the com...   None     None
# 3  The fund employs an indexing investment approa...   None     None
#
#   Current_Price    Market_Cap Ebitda  ...  Date_Short_Interest  \
# 0          None           NaN   None  ...                 None
# 1          None  6.071404e+11   None  ...                 None
# 2          None  2.351760e+11   None  ...                 None
# 3          None           NaN   None  ...                 None
#
#    Shares_Percent_Shares_Out Short_Ratio  Short_Percent_Of_Float  \
# 0                       None        None                    None
# 1                       None        None                    None
# 2                       None        None                    None
# 3                       None        None                    None
#
#    Last_Fiscal_Year_End  Next_Fiscal_Year_End  Most_Recent_Quarter  \
# 0                  None                  None                 None
# 1                  None                  None                 None
# 2                  None                  None                 None
# 3                  None                  None                 None
#
#   Earnings_Quarterly_Growth  Net_Income_To_Common Average_Analyst_Rating
# 0                      None                  None                   None
# 1                      None                  None                   None
# 2                      None                  None                   None
# 3                      None                  None                   None
#
# [4 rows x 37 columns]

# %%
info.get("revenueGrowth")

# %%
ticker = yf.Ticker('SPY')
info = ticker.info
ticker.info
# Out:
# {'longBusinessSummary': 'The trust seeks to achieve its investment objective by holding a portfolio of the common stocks that are included in the index, with the weight of each stock in the portfolio substantially corresponding to the weight of such stock in the index.',
#  'companyOfficers': [],
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 665.67,
#  'open': 662.095,
#  'dayLow': 656.8,
#  'dayHigh': 664.26,
#  'regularMarketPreviousClose': 665.67,
#  'regularMarketOpen': 662.095,
#  'regularMarketDayLow': 656.8,
#  'regularMarketDayHigh': 664.26,
#  'trailingPE': 27.747684,
#  'volume': 39784590,
#  'regularMarketVolume': 39784590,
#  'averageVolume': 75880214,
#  'averageVolume10days': 82608640,
#  'averageDailyVolume10Day': 82608640,
#  'bid': 658.29,
#  'ask': 658.48,
#  'bidSize': 880,
#  'askSize': 480,
#  'yield': 0.0109,
#  'totalAssets': 672726646784,
#  'fiftyTwoWeekLow': 481.8,
#  'fiftyTwoWeekHigh': 689.7,
#  'allTimeHigh': 689.7,
#  'allTimeLow': 42.8125,
#  'fiftyDayAverage': 668.8152,
#  'twoHundredDayAverage': 613.47156,
#  'trailingAnnualDividendRate': 5.662,
#  'trailingAnnualDividendYield': 0.008505717,
#  'navPrice': 671.2819,
#  'currency': 'USD',
#  'tradeable': False,
#  'category': 'Large Blend',
#  'ytdReturn': 14.74103,
#  'beta3Year': 1.0,
#  'fundFamily': 'SPDR State Street Investment Management',
#  'fundInceptionDate': 727660800,
#  'legalType': 'Exchange Traded Fund',
#  'threeYearAverageReturn': 0.241714,
#  'fiveYearAverageReturn': 0.1596985,
#  'quoteType': 'ETF',
#  'symbol': 'SPY',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'ETF',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'marketState': 'REGULAR',
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 728317800000,
#  'shortName': 'SPDR S&P 500',
#  'longName': 'SPDR S&P 500 ETF',
#  'corporateActions': [],
#  'regularMarketTime': 1763481603,
#  'exchange': 'PCX',
#  'regularMarketChangePercent': -1.2814109,
#  'regularMarketPrice': 657.14,
#  'messageBoardId': 'finmb_6160262',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'regularMarketChange': -8.529968,
#  'regularMarketDayRange': '656.8 - 664.26',
#  'fullExchangeName': 'NYSEArca',
#  'financialCurrency': 'USD',
#  'averageDailyVolume3Month': 75880214,
#  'fiftyTwoWeekLowChange': 175.34003,
#  'fiftyTwoWeekLowChangePercent': 0.363927,
#  'fiftyTwoWeekRange': '481.8 - 689.7',
#  'fiftyTwoWeekHighChange': -32.559998,
#  'fiftyTwoWeekHighChangePercent': -0.047208928,
#  'fiftyTwoWeekChangePercent': 12.768089,
#  'dividendYield': 1.09,
#  'trailingThreeMonthReturns': 8.08677,
#  'trailingThreeMonthNavReturns': 8.08677,
#  'netAssets': 672726650000.0,
#  'epsTrailingTwelveMonths': 23.682697,
#  'sharesOutstanding': 917782016,
#  'bookValue': 429.22,
#  'fiftyDayAverageChange': -11.675171,
#  'fiftyDayAverageChangePercent': -0.017456498,
#  'twoHundredDayAverageChange': 43.668457,
#  'twoHundredDayAverageChangePercent': 0.07118253,
#  'netExpenseRatio': 0.0945,
#  'marketCap': 603111292928,
#  'priceToBook': 1.5310098,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'cryptoTradeable': False,
#  'trailingPegRatio': None}

# %%
ticker = yf.Ticker('NVDA')
info = ticker.info
ticker.info
# Out:
# {'address1': '2788 San Tomas Expressway',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95051',
#  'country': 'United States',
#  'phone': '408 486 2000',
#  'website': 'https://www.nvidia.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': "NVIDIA Corporation, a computing infrastructure company, provides graphics and compute and networking solutions in the United States, Singapore, Taiwan, China, Hong Kong, and internationally. The Compute & Networking segment includes its Data Centre accelerated computing platforms and artificial intelligence solutions and software; networking; automotive platforms and autonomous and electric vehicle solutions; Jetson for robotics and other embedded platforms; and DGX Cloud computing services. The Graphics segment offers GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU or vGPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems; and Omniverse software for building and operating industrial AI and digital twin applications. It also customized agentic solutions designed in collaboration with NVIDIA to accelerate enterprise AI adoption. The company's products are used in gaming, professional visualization, data center, and automotive markets. It sells its products to original equipment manufacturers, original device manufacturers, system integrators and distributors, independent software vendors, cloud service providers, consumer internet companies, add-in board manufacturers, distributors, automotive manufacturers and tier-1 automotive suppliers, and other ecosystem participants. NVIDIA Corporation was incorporated in 1993 and is headquartered in Santa Clara, California.",
#  'fullTimeEmployees': 36000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Jen-Hsun  Huang',
#    'age': 61,
#    'title': 'Co-Founder, CEO, President & Director',
#    'yearBorn': 1963,
#    'fiscalYear': 2025,
#    'totalPay': 11054945,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Colette M. Kress',
#    'age': 57,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1967,
#    'fiscalYear': 2025,
#    'totalPay': 1512641,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Debora  Shoquist',
#    'age': 69,
#    'title': 'Executive Vice President of Operations',
#    'yearBorn': 1955,
#    'fiscalYear': 2025,
#    'totalPay': 1379071,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Timothy S. Teter J.D.',
#    'age': 57,
#    'title': 'Executive VP, General Counsel & Secretary',
#    'yearBorn': 1967,
#    'fiscalYear': 2025,
#    'totalPay': 1362989,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Ajay K. Puri',
#    'age': 69,
#    'title': 'Executive Vice President of Worldwide Field Operations',
#    'yearBorn': 1955,
#    'fiscalYear': 2025,
#    'totalPay': 2313851,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris A. Malachowsky',
#    'title': 'Co-Founder',
#    'fiscalYear': 2025,
#    'totalPay': 320000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Donald F. Robertson Jr.',
#    'age': 55,
#    'title': 'VP & Chief Accounting Officer',
#    'yearBorn': 1969,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Prof. William J. Dally Ph.D.',
#    'age': 63,
#    'title': 'Chief Scientist & Senior VP of Research',
#    'yearBorn': 1961,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Toshiya  Hari',
#    'title': 'Vice President of Investor Relations & Strategic Finance',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Mylene  Mangalindan',
#    'title': 'VP of Corporate Communications',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 5,
#  'boardRisk': 10,
#  'compensationRisk': 4,
#  'shareHolderRightsRisk': 8,
#  'overallRisk': 8,
#  'governanceEpochDate': 1761955200,
#  'compensationAsOfEpochDate': 1767139200,
#  'irWebsite': 'http://phx.corporate-ir.net/phoenix.zhtml?c=116466&p=irol-IRHome',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 186.6,
#  'open': 183.33,
#  'dayLow': 179.65,
#  'dayHigh': 184.27,
#  'regularMarketPreviousClose': 186.6,
#  'regularMarketOpen': 183.33,
#  'regularMarketDayLow': 179.65,
#  'regularMarketDayHigh': 184.27,
#  'dividendRate': 0.04,
#  'dividendYield': 0.02,
#  'exDividendDate': 1757548800,
#  'payoutRatio': 0.0114,
#  'fiveYearAvgDividendYield': 0.06,
#  'beta': 2.269,
#  'trailingPE': 52.136753,
#  'forwardPE': 44.417477,
#  'volume': 95993772,
#  'regularMarketVolume': 95990121,
#  'averageVolume': 185197520,
#  'averageVolume10days': 194539350,
#  'averageDailyVolume10Day': 194539350,
#  'bid': 182.7,
#  'ask': 183.06,
#  'bidSize': 1,
#  'askSize': 1,
#  'marketCap': 4462922956800,
#  'fiftyTwoWeekLow': 86.62,
#  'fiftyTwoWeekHigh': 212.19,
#  'allTimeHigh': 212.19,
#  'allTimeLow': 0.033333,
#  'priceToSalesTrailing12Months': 27.012936,
#  'fiftyDayAverage': 185.974,
#  'twoHundredDayAverage': 151.5237,
#  'trailingAnnualDividendRate': 0.04,
#  'trailingAnnualDividendYield': 0.00021436226,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 4488186822656,
#  'profitMargins': 0.52414,
#  'floatShares': 23328486000,
#  'sharesOutstanding': 24347000000,
#  'sharesShort': 238599888,
#  'sharesShortPriorMonth': 226771413,
#  'sharesShortPreviousMonthDate': 1759190400,
#  'dateShortInterest': 1761868800,
#  'sharesPercentSharesOut': 0.0098,
#  'heldPercentInsiders': 0.0433,
#  'heldPercentInstitutions': 0.69278,
#  'shortRatio': 1.34,
#  'shortPercentOfFloat': 0.010199999,
#  'impliedSharesOutstanding': 24387557065,
#  'bookValue': 4.113,
#  'priceToBook': 44.493073,
#  'lastFiscalYearEnd': 1737849600,
#  'nextFiscalYearEnd': 1769385600,
#  'mostRecentQuarter': 1753574400,
#  'earningsQuarterlyGrowth': 0.592,
#  'netIncomeToCommon': 86597001216,
#  'trailingEps': 3.51,
#  'forwardEps': 4.12,
#  'lastSplitFactor': '10:1',
#  'lastSplitDate': 1717977600,
#  'enterpriseToRevenue': 27.165,
#  'enterpriseToEbitda': 45.667,
#  '52WeekChange': 0.2693014,
#  'SandP52WeekChange': 0.1276716,
#  'lastDividendValue': 0.01,
#  'lastDividendDate': 1757548800,
#  'quoteType': 'EQUITY',
#  'currentPrice': 183.0041,
#  'targetHighPrice': 350.0,
#  'targetLowPrice': 140.0,
#  'targetMeanPrice': 234.95631,
#  'targetMedianPrice': 230.0,
#  'recommendationMean': 1.34375,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 57,
#  'totalCash': 56790999040,
#  'totalCashPerShare': 2.337,
#  'ebitda': 98280996864,
#  'totalDebt': 10597999616,
#  'quickRatio': 3.488,
#  'currentRatio': 4.214,
#  'totalRevenue': 165217992704,
#  'debtToEquity': 10.584,
#  'revenuePerShare': 6.755,
#  'returnOnAssets': 0.53094,
#  'returnOnEquity': 1.09417,
#  'grossProfits': 115399999488,
#  'freeCashflow': 52436750336,
#  'operatingCashflow': 77035003904,
#  'earningsGrowth': 0.612,
#  'revenueGrowth': 0.556,
#  'grossMargins': 0.69847,
#  'ebitdaMargins': 0.59486,
#  'operatingMargins': 0.60842997,
#  'financialCurrency': 'USD',
#  'symbol': 'NVDA',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 917015400000,
#  'regularMarketChange': -3.600006,
#  'regularMarketDayRange': '179.65 - 184.27',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 185197520,
#  'fiftyTwoWeekLowChange': 96.38,
#  'fiftyTwoWeekLowChangePercent': 1.112676,
#  'fiftyTwoWeekRange': '86.62 - 212.19',
#  'fiftyTwoWeekHighChange': -29.190002,
#  'fiftyTwoWeekHighChangePercent': -0.1375654,
#  'fiftyTwoWeekChangePercent': 26.930141,
#  'dividendDate': 1759363200,
#  'earningsTimestamp': 1763586000,
#  'earningsTimestampStart': 1763586000,
#  'earningsTimestampEnd': 1763586000,
#  'earningsCallTimestampStart': 1763589600,
#  'earningsCallTimestampEnd': 1763589600,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 3.51,
#  'epsForward': 4.12,
#  'epsCurrentYear': 4.56345,
#  'priceEpsCurrentYear': 40.101242,
#  'fiftyDayAverageChange': -2.973999,
#  'fiftyDayAverageChangePercent': -0.015991477,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_32307',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': -1.9291604,
#  'regularMarketPrice': 183.0,
#  'corporateActions': [],
#  'regularMarketTime': 1763483352,
#  'twoHundredDayAverageChange': 31.476303,
#  'twoHundredDayAverageChangePercent': 0.20773189,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'prevName': 'Usual Stablecoin',
#  'nameChangeDate': '2025-11-17',
#  'averageAnalystRating': '1.3 - Strong Buy',
#  'cryptoTradeable': False,
#  'shortName': 'NVIDIA Corporation',
#  'longName': 'NVIDIA Corporation',
#  'marketState': 'REGULAR',
#  'displayName': 'NVIDIA',
#  'trailingPegRatio': 0.8042}

# %%
# Get CEO
info.get("companyOfficers")[0].get("name")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[78], line 2
#       1 # Get CEO
# ----> 2 info.get("companyOfficers")[0].get("name")
#
# IndexError: list index out of range

# %%
 # 'fullTimeEmployees': 190167,
 # 'companyOfficers': [{'maxAge': 1,
 #   'name': 'Mr. Sundar  Pichai',
 #   'age': 51,
 #   'title': 'CEO & Director',
 #   'yearBorn': 1973,
 #   'fiscalYear': 2024,
 #   'totalPay': 10319413,
 #   'exercisedValue': 0,
 #   'unexercisedValue': 0},
 #  {'maxAge': 1,
 #   'name': 'Ms. Ruth M. Porat',
 #   'age': 66,
 #   'title': 'President & Chief Investment Officer',
 #   'yearBorn': 1958,
 #   'fiscalYear': 2024,
 #   'totalPay': 3023363,
 #   'exercisedValue': 0,
 #   'unexercisedValue': 0},
 #  {'maxAge': 1,
 #   'name': 'Dr. Lawrence Edward Page II',
 #   'age': 51,
 #   'title': 'Co-Founder & Director',
 #   'yearBorn': 1973,
 #   'fiscalYear': 2024,
 #   'totalPay': 1,
 #   'exercisedValue': 0,
 #   'unexercisedValue': 0},
 #  {'maxAge': 1,
 #   'name': 'Mr. Sergey  Brin',
 #   'age': 50,
 #   'title': 'Co-Founder & Director',
 #   'yearBorn': 1974,
 #   'fiscalYear': 2024,
 #   'totalPay': 1,
 #   'exercisedValue': 0,
 #   'unexercisedValue': 0},
 #  {'maxAge': 1,
 #   'name': 'Ms. Anat  Ashkenazi',
 #   'age': 51,
 #   'title': 'Senior VP & CFO',
 #   'yearBorn': 1973,
 #   'fiscalYear': 2024,
 #   'totalPay': 11455556,
 #   'exercisedValue': 0,
 #   'unexercisedValue': 0},
 #  {'maxAge': 1,
 #   'name': 'Mr. J. Kent Walker',
 #   'age': 63,
 #   'title': 'President of Global Affairs, Chief Legal Officer & Company Secretary',
 #   'yearBorn': 1961,
 #   'fiscalYear': 2024,
 #   'totalPay': 3019696,
 #   'exercisedValue': 0,
 #   'unexercisedValue': 0},
 #  {'maxAge': 1,
 #   'name': 'Mr. Philipp  Schindler',
 #   'age': 53,
 #   'title': 'Senior Vice President & Chief Business Officer of Google',
 #   'yearBorn': 1971,
 #   'fiscalYear': 2024,
 #   'totalPay': 3051699,
 #   'exercisedValue': 0,
 #   'unexercisedValue': 0},
 #  {'maxAge': 1,
 #   'name': "Ms. Amie Thuener O'Toole",
 #   'age': 49,
 #   'title': 'Corporate Controller, Chief Accounting Officer & VP',
 #   'yearBorn': 1975,
 #   'fiscalYear': 2024,
 #   'exercisedValue': 0,
 #   'unexercisedValue': 0},
 #  {'maxAge': 1,
 #   'name': 'Ms. Ellen  West',
 #   'title': 'Vice President of Investor Relations',
 #   'fiscalYear': 2024,
 #   'exercisedValue': 0,
 #   'unexercisedValue': 0},
 #  {'maxAge': 1,
 #   'name': 'Ms. Fiona Clare Cicconi',
 #   'age': 58,
 #   'title': 'Chief People Officer',
 #   'yearBorn': 1966,
 #   'fiscalYear': 2024,
 #   'exercisedValue': 0,
 #   'unexercisedValue': 0}],
 # 'auditRisk': 7,
